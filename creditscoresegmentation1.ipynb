# %% [markdown]
# <a href="https://www.kaggle.com/code/somashekar39/creditscoresegmentation1?scriptVersionId=185247786" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio

# %%
import os
print(os.listdir("../input/credit"))

# %%
data = pd.read_csv('../input/credit/credit_scoring.csv')

# %%
data.head()

# %%
data.describe()

# %%
data.info()

# %%
data.shape

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data['Credit Utilization Ratio'])
plt.show()

# %%
credit_utilization = px.box(data['Credit Utilization Ratio'])
credit_utilization.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data,x='Loan Amount',bins=30)
plt.title('Loan Amount Distribution')
plt.show()

# %%
loanAmount_hist = px.histogram(data,x='Loan Amount',nbins=20,title='Loan Amount Distribution')
loanAmount_hist.update_layout(
    width=500,
    height=500,
)
loanAmount_hist.show()

# %%
sns.heatmap(data.corr(numeric_only=True))
plt.title('Correlation')
plt.show()

# %%
df = data[['Credit Utilization Ratio','Payment History','Number of Credit Accounts','Loan Amount','Interest Rate','Loan Term']]
corr_fig = px.imshow(df.corr(),title='Correlation Heatmanp')
corr_fig.update_layout(
    width=600,
    height=600,
)
corr_fig.show()

# %%
data.info()

# %%
education_level = {'High School':1,'Bachelor':2,'Master':3,'PhD':4}
employment_status = {'Unemployed':0,'Self-Employed':2,'Employed':1}
data['Education Level'] = data['Education Level'].map(education_level)
data['Employment Status'] = data['Employment Status'].map(employment_status)

# %%
# edication_level = {'High School':1,'Bachelor':2,'Master':3,'PhD':4}
# employment_status = {'Unemployed':0,'Self-Employed':2,'Employed':1}
# data['Education Level'] = data['Education Level'].map(education_level)
# data['Employment Status'] = data['Employment Status'].map(employment_status)
# credit_scores = []
# for index,row in data.iterrows():
#     ph = row['Payment History']
#     cur = row['Credit Utilization Ratio']
#     nca = row['Number of Credit Accounts']
#     el = row['Education Level']
#     es = row['Employment Status']
#     credit_score = (payment_history * 0.35) + (credit_utilization_ratio * 0.30) + (number_of_credit_accounts * 0.15) + (education_level * 0.10) + (employment_status * 0.10)
#     credit_scores.append(credit_score)

# %%
data['Credit Score'] = data['Payment History']*0.35+data['Credit Utilization Ratio']*0.30+data['Number of Credit Accounts']*0.15+data['Education Level']*0.10+data['Employment Status']*0.10
data.head()

# %%
data.head()

# %%
from sklearn.cluster import KMeans
X = data[['Credit Score']]
kmeans = KMeans(n_clusters=4,n_init=10,random_state = 42)
kmeans.fit(X)
data['Segment'] = kmeans.labels_

# %%
data['Segment'] = data['Segment'].astype('category')

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data,x=data.index,y='Credit Score',hue='Segment',palette='Set1')
plt.xlabel('Index')
plt.title('Customer Segmentation based on credit score')
plt.show()

# %%
pio.templates.default = "plotly_white"
fig = px.scatter(data,x=data.index,y='Credit Score',color='Segment',color_discrete_sequence=['green','blue','yellow','red'])
fig.update_layout(
    xaxis_title='Customer Index',
    yaxis_title='Credit Score',
    title='Customer segmentation based on Credit score'
)
fig.show()

# %%
data['Segment'] = data['Segment'].map({2:'Very Low',0:'Low',1:'Good',3:'Excellent'})
# data['Segment'] = data['Segment'].astype('category')
fig = px.scatter(data,x=data.index,y='Credit Score',color='Segment',color_discrete_sequence=['green','blue','yellow','red'])
fig.update_layout(
    xaxis_title='Customer Index',
    yaxis_title='Credit Score',
    title='Customer segmentation based on Credit score'
)
fig.show()
